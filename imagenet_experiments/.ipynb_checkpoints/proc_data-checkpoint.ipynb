# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline  
from matplotlib.font_manager import FontProperties

# %%
df = pd.read_csv('ILA_projection_all.csv')

# %%
baseline = df[df.with_fla == False].groupby(['source_model', 'target_model','fool_method'])[['acc_after_attack','fool_rate','original_acc']].mean().reset_index()
baseline
# Out:
#      source_model   target_model     fool_method  acc_after_attack  fool_rate  \
# 0     DenseNet121    DenseNet121           ifgsm          0.050000  86.930000
# 1     DenseNet121    DenseNet121  momentum_ifgsm          0.088636  87.484091
# 2     DenseNet121       ResNet18           ifgsm         52.288000  26.074000
# 3     DenseNet121       ResNet18  momentum_ifgsm         36.720455  47.215909
# 4     DenseNet121  SqueezeNet1.0           ifgsm         47.794000  21.160000
# 5     DenseNet121  SqueezeNet1.0  momentum_ifgsm         37.072727  40.625000
# 6     DenseNet121        alexnet           ifgsm         54.044000   9.108000
# 7     DenseNet121        alexnet  momentum_ifgsm         50.150000  21.225000
# 8        ResNet18    DenseNet121           ifgsm         56.891795  25.249920
# 9        ResNet18    DenseNet121  momentum_ifgsm         41.222809  45.517434
# 10       ResNet18       ResNet18           ifgsm          0.017994  87.248081
# 11       ResNet18       ResNet18  momentum_ifgsm          0.021993  87.679942
# 12       ResNet18  SqueezeNet1.0           ifgsm         44.233845  26.513516
# 13       ResNet18  SqueezeNet1.0  momentum_ifgsm         33.023433  46.367163
# 14       ResNet18        alexnet           ifgsm         52.957054  10.806542
# 15       ResNet18        alexnet  momentum_ifgsm         49.228247  22.412828
# 16  SqueezeNet1.0    DenseNet121           ifgsm         60.638596  22.392834
# 17  SqueezeNet1.0    DenseNet121  momentum_ifgsm         51.060169  38.410302
# 18  SqueezeNet1.0       ResNet18           ifgsm         49.904031  31.735845
# 19  SqueezeNet1.0       ResNet18  momentum_ifgsm         36.689609  52.342362
# 20  SqueezeNet1.0  SqueezeNet1.0           ifgsm          0.025992  87.715931
# 21  SqueezeNet1.0  SqueezeNet1.0  momentum_ifgsm          0.044405  90.719361
# 22  SqueezeNet1.0        alexnet           ifgsm         50.581814  15.668986
# 23  SqueezeNet1.0        alexnet  momentum_ifgsm         48.828819  28.424734
# 24        alexnet    DenseNet121           ifgsm         68.845969  12.869882
# 25        alexnet    DenseNet121  momentum_ifgsm         63.671625  21.387156
# 26        alexnet       ResNet18           ifgsm         61.136436  17.596369
# 27        alexnet       ResNet18  momentum_ifgsm         54.004718  29.382598
# 28        alexnet  SqueezeNet1.0           ifgsm         47.116923  24.304223
# 29        alexnet  SqueezeNet1.0  momentum_ifgsm         38.669626  40.243122
# 30        alexnet        alexnet           ifgsm          0.063980  88.681622
# 31        alexnet        alexnet  momentum_ifgsm          0.059981  89.383397
#
#     original_acc
# 0      74.434000
# 1      74.736364
# 2      69.758000
# 3      69.909091
# 4      58.092000
# 5      57.936364
# 6      56.522000
# 7      56.381818
# 8      74.426184
# 9      74.426184
# 10     69.753679
# 11     69.753679
# 12     58.079415
# 13     58.079415
# 14     56.507917
# 15     56.507917
# 16     74.426184
# 17     79.790187
# 18     69.753679
# 19     74.816829
# 20     58.079415
# 21     64.958925
# 22     56.507917
# 23     62.710924
# 24     74.426184
# 25     74.426184
# 26     69.753679
# 27     69.753679
# 28     58.079415
# 29     58.079415
# 30     56.507917
# 31     56.507917

# %%
q = df[(df.with_fla == True)].groupby(['source_model', 'target_model','fool_method','layer_index'])['acc_after_attack'].mean().reset_index()
q
# Out:
#    source_model   target_model fool_method  layer_index  acc_after_attack
# 0      ResNet18    DenseNet121       ifgsm            0           43.3750
# 1      ResNet18    DenseNet121       ifgsm            1           48.3750
# 2      ResNet18    DenseNet121       ifgsm            2           45.5000
# 3      ResNet18    DenseNet121       ifgsm            3           38.3750
# 4      ResNet18    DenseNet121       ifgsm            4           38.5000
# 5      ResNet18    DenseNet121       ifgsm            5           53.4375
# 6      ResNet18    DenseNet121       ifgsm            6           54.8125
# 7      ResNet18       ResNet18       ifgsm            0            0.0000
# 8      ResNet18       ResNet18       ifgsm            1            0.0000
# 9      ResNet18       ResNet18       ifgsm            2            0.0000
# 10     ResNet18       ResNet18       ifgsm            3            0.0000
# 11     ResNet18       ResNet18       ifgsm            4            0.0625
# 12     ResNet18       ResNet18       ifgsm            5            0.0000
# 13     ResNet18       ResNet18       ifgsm            6            0.0000
# 14     ResNet18  SqueezeNet1.0       ifgsm            0           31.3125
# 15     ResNet18  SqueezeNet1.0       ifgsm            1           36.0625
# 16     ResNet18  SqueezeNet1.0       ifgsm            2           33.3750
# 17     ResNet18  SqueezeNet1.0       ifgsm            3           29.6250
# 18     ResNet18  SqueezeNet1.0       ifgsm            4           31.4375
# 19     ResNet18  SqueezeNet1.0       ifgsm            5           41.9375
# 20     ResNet18  SqueezeNet1.0       ifgsm            6           43.3125
# 21     ResNet18        alexnet       ifgsm            0           46.8750
# 22     ResNet18        alexnet       ifgsm            1           49.6250
# 23     ResNet18        alexnet       ifgsm            2           51.8125
# 24     ResNet18        alexnet       ifgsm            3           50.8750
# 25     ResNet18        alexnet       ifgsm            4           50.5625
# 26     ResNet18        alexnet       ifgsm            5           53.0625
# 27     ResNet18        alexnet       ifgsm            6           53.4375

# %%
layer_selection = {'DenseNet121': 7, 'GoogLeNet': 9,'ResNet18': 4,'SENet18': 4}
# select = q[q.layer_index == layer_selection[q.source_model]]
# select
layer_selected = q[q.layer_index == q.source_model.apply(lambda a : layer_selection[a])].reset_index()
layer_selected = layer_selected.drop(['index'], axis=1)
layer_selected

# %%
optimum = q.groupby(['source_model','target_model','fool_method']).apply(lambda x: x[x.acc_after_attack == x.acc_after_attack.min()][['layer_index', 'acc_after_attack']]).reset_index()
optimum = optimum.drop(['level_3'], axis=1)
optimum

# %%
compare = layer_selected.merge(optimum, on = ['source_model','target_model','fool_method'], suffixes = ["","_opt"])
compare = compare.merge(baseline, on = ['source_model','target_model','fool_method'], suffixes = ["","_baseline"])
compare

# %%
def visualize_result(name):
    df = pd.read_csv(name)
#     df = df[(df.source_model == 'ResNet18') & (df.fool_method == 'ifgsm')]
    source_models = df.source_model.unique()
    target_models =  df.target_model.unique()
    attacks = df.fool_method.unique()
    metrics = ['acc_after_attack']
    for metric in metrics:
        
        for source_model in source_models:
#             fig = plt.figure()
            fig = plt.figure(figsize = [6*len(attacks), 4])
            shared_ax = None
            for i, attack in enumerate(attacks):
                
                if shared_ax == None:
                    shared_ax = plt.subplot(1,len(attacks),i+1)
                else:
                    plt.subplot(1,len(attacks),i+1, sharey=shared_ax)
                
                layer_indexs = df[df.source_model == source_model]['layer_index'].unique()[1:]
                layer_names = df[df.source_model == source_model]['layer_name'].unique()[1:]
                print(layer_names)
                for target_model in target_models:           
                    r = df[(df.source_model == source_model) & (df.target_model == target_model) & (df.fool_method == attack)]
                    
                    fla = r[r.with_fla].groupby('layer_index')
                    other = r[r.with_fla == False]
#                     print(other)
                    xs = fla.layer_index.unique()
                    baseline = other[metric].mean()
                    fla_r = fla[metric].mean()
                    names = fla.layer_name.unique()
#                     print(source_model)
#                     print(target_model)
#                     print(attack)
#                     print([baseline for i in xs])
                    p = plt.plot(layer_indexs,  [baseline for i in xs], linestyle = '--', label = target_model)
                    plt.plot(fla_r, label =  target_model + " ILAP", color = p[0]._color)
#                     plt.xticks(layer_indexs, layer_names)
                    if source_model != target_model and ((metric == 'fool_rate' and not(fla_r > baseline).any())or (metric == 'acc_after_attack' and not(fla_r < baseline).any())):
                        print("never perform absolutely better: " + source_model + " " + target_model)
                
#                 plt.ylim([-5,75])
                plt.ylabel('Accuracy after Attack')
                plt.xlabel('Layer Index')
                fontP = FontProperties()
                fontP.set_size('small')
                
                plt.legend(ncol = 3, loc=[0,-0.5], prop=fontP)
#                 if attack == 'ifgsm':
#                     plt.title( "ifgsm, source:" + source_model)
#                 if attack == 'momentum_ifgsm':
#                     plt.title("momentum_ifgsm, source:" + source_model )
             
#                 plt.title(attack + " source:" + source_model)
                plt.title('I-FGSM and ILAP attack based on {}'.format(source_model))
            plt.show()
                
            fig.savefig( 'ILA_projection_imagenet_all_source:{}.pdf'.format(source_model))
#             fig.savefig( 'ILAP_IFGSM_resnet_imagenet.pdf')

# %%
visualize_result('ILA_projection_all.csv')
# Out:
# ['conv1' 'bn1' 'layer1' 'layer2' 'layer3' 'layer4' 'fc']
# ['conv1' 'bn1' 'layer1' 'layer2' 'layer3' 'layer4' 'fc']
# ['conv0' 'denseblock1' 'transition1' 'denseblock2' 'transition2'
#  'denseblock3' 'transition3' 'denseblock4' 'norm5' 'classifier']
# ['conv0' 'denseblock1' 'transition1' 'denseblock2' 'transition2'
#  'denseblock3' 'transition3' 'denseblock4' 'norm5' 'classifier']
# ['layer 0' 'layer 3' 'layer 4' 'layer 5' 'layer 7' 'layer 8' 'layer 9'
#  'layer 10' 'layer 12' 'classifier']
# ['layer 0' 'layer 3' 'layer 4' 'layer 5' 'layer 7' 'layer 8' 'layer 9'
#  'layer 10' 'layer 12' 'classifier']
# ['layer 0' 'layer 3' 'layer 6' 'layer 8' 'layer 10' 'layer 1' 'layer 4']
# ['layer 0' 'layer 3' 'layer 6' 'layer 8' 'layer 10' 'layer 1' 'layer 4']
